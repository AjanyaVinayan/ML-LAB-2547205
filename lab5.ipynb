# %% [markdown]
# <a href="https://colab.research.google.com/github/AjanyaVinayan/ML-LAB-2547205/blob/LAB---5/lab5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Task 1: Download and Load the Student Performance Dataset
#
# *(See code cells below for loading `student-mat.csv` into `df` and `student-por.csv` into `fd`)*

# %%
import pandas as pd

# Load the student-mat.csv file directly from the content directory
df = pd.read_csv('/content/student-mat.csv', sep=';') # Data is semicolon-separated

print("Dataset loaded successfully.")

# Display the first 5 rows of the DataFrame
display(df.head())
# Out:
# Dataset loaded successfully.
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
print("Number of Records (Rows):", df.shape[0])
print("Number of Features (Columns):", df.shape[1])
# Out:
# Number of Records (Rows): 395
# Number of Features (Columns): 33

# %%
# Load the student-mat.csv file directly from the content directory
fd = pd.read_csv('/content/student-por.csv', sep=';') # Data is semicolon-separated

print("Dataset loaded successfully.")

# Display the first 5 rows of the DataFrame
display(fd.head())
# Out:
# Dataset loaded successfully.
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
print("Number of Records (Rows):", fd.shape[0])
print("Number of Features (Columns):", fd.shape[1])
# Out:
# Number of Records (Rows): 649
# Number of Features (Columns): 33

# %% [markdown]
# # Task 2: Perform Data Preprocessing

# %%
# Display basic information about the DataFrame, including data types and non-null counts
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
# Check for missing values in each column
print("\nMissing values per column:")
print(df.isnull().sum())
# Out:
# Missing values per column:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %% [markdown]
# ### One-Hot Encoding for Categorical Variables

# %%
categorical_cols = df.select_dtypes(include=['object']).columns
print(categorical_cols)
# Out:
# Index(['school', 'sex', 'address', 'famsize', 'Pstatus', 'Mjob', 'Fjob',
#        'reason', 'guardian', 'schoolsup', 'famsup', 'paid', 'activities',
#        'nursery', 'higher', 'internet', 'romantic'],
#       dtype='object')

# %%
# Apply one-hot encoding to categorical columns
df_encoded = pd.get_dummies(df, columns=categorical_cols, drop_first=True)

print("DataFrame after one-hot encoding:")
display(df_encoded.head())
# Out:
# DataFrame after one-hot encoding:
#    age  Medu  Fedu  traveltime  studytime  failures  famrel  freetime  goout  \
# 0   18     4     4           2          2         0       4         3      4
# 1   17     1     1           1          2         0       5         3      3
# 2   15     1     1           1          2         3       4         3      2
# 3   15     4     2           1          3         0       3         2      2
# 4   16     3     3           1          2         0       4         3      2
#
#    Dalc  ...  guardian_mother  guardian_other  schoolsup_yes  famsup_yes  \
# 0     1  ...             True           False           True       False
# 1     1  ...            False           False          False        True
# 2     2  ...             True           False           True       False
# 3     1  ...             True           False          False        True
# 4     1  ...            False           False          False        True
#
# ...

# %%
# Select features (X) and target (y)
# G3 is the final grade, which will be our target variable.
# G1 and G2 are previous period grades and can lead to data leakage if used as features for predicting G3.
# We will drop G1, G2, and G3 from the features.
X = df_encoded.drop(columns=['G1', 'G2', 'G3'])
y = df_encoded['G3']

print(f"Shape of features (X): {X.shape}")
print(f"Shape of target (y): {y.shape}")
# Out:
# Shape of features (X): (395, 39)
# Shape of target (y): (395,)

# %% [markdown]
# # Task 4: Split the Dataset into Training and Testing Sets

# %% [markdown]
# ### Feature Scaling
#
# Before splitting the data, it's good practice to scale the features. This is particularly important for Gradient Descent, as it helps the algorithm converge faster and avoids issues where features with larger scales dominate the cost function.

# %%
from sklearn.preprocessing import StandardScaler

# Initialize the StandardScaler
scaler = StandardScaler()

# Fit the scaler to the features and transform them
X_scaled = scaler.fit_transform(X)

# Convert scaled features back to a DataFrame for easier inspection (optional, but good for understanding)
X_scaled_df = pd.DataFrame(X_scaled, columns=X.columns)

print("First 5 rows of scaled features:")
display(X_scaled_df.head())
# Out:
# First 5 rows of scaled features:
#         age      Medu      Fedu  traveltime  studytime  failures    famrel  \
# 0  1.023046  1.143856  1.360371    0.792251  -0.042286 -0.449944  0.062194
# 1  0.238380 -1.600009 -1.399970   -0.643249  -0.042286 -0.449944  1.178860
# 2 -1.330954 -1.600009 -1.399970   -0.643249  -0.042286  3.589323  0.062194
# 3 -1.330954  1.143856 -0.479857   -0.643249   1.150779 -0.449944 -1.054472
# 4 -0.546287  0.229234  0.440257   -0.643249  -0.042286 -0.449944  0.062194
#
#    freetime     goout      Dalc  ...  guardian_mother  guardian_other  \
# 0 -0.236010  0.801479 -0.540699  ...         0.668496       -0.296908
# 1 -0.236010 -0.097908 -0.540699  ...        -1.495896       -0.296908
# 2 -0.236010 -0.997295  0.583385  ...         0.668496       -0.296908
# 3 -1.238419 -0.997295 -0.540699  ...         0.668496       -0.296908
# 4 -0.236010 -0.997295 -0.540699  ...        -1.495896       -0.296908
#
# ...

# %% [markdown]
# # Task 3: Select Appropriate Input Features and the Target Variable

# %%
from sklearn.model_selection import train_test_split

# Split the dataset into training and testing sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

print(f"X_train shape: {X_train.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# X_train shape: (316, 39)
# X_test shape: (79, 39)
# y_train shape: (316,)
# y_test shape: (79,)

# %% [markdown]
# # Task 5: Implement Linear Regression using the Gradient Descent Algorithm

# %%
import numpy as np

class LinearRegressionGD:
    def __init__(self, learning_rate=0.01, n_iterations=1000):
        self.learning_rate = learning_rate
        self.n_iterations = n_iterations
        self.weights = None
        self.bias = None
        self.cost_history = []

    def fit(self, X, y):
        # Initialize weights and bias
        n_samples, n_features = X.shape
        self.weights = np.zeros(n_features)
        self.bias = 0

        # Gradient Descent
        for i in range(self.n_iterations):
            # Calculate predictions
            y_predicted = np.dot(X, self.weights) + self.bias

            # Calculate gradients
            dw = (1/n_samples) * np.dot(X.T, (y_predicted - y))
            db = (1/n_samples) * np.sum(y_predicted - y)

            # Update weights and bias
            self.weights -= self.learning_rate * dw
            self.bias -= self.learning_rate * db

            # Calculate and store the cost (Mean Squared Error)
            cost = (1/n_samples) * np.sum((y_predicted - y)**2)
            self.cost_history.append(cost)

    def predict(self, X):
        return np.dot(X, self.weights) + self.bias

print("LinearRegressionGD class defined.")
# Out:
# LinearRegressionGD class defined.

# %% [markdown]
# # Task 6: Experiment with Different Learning Rates and Observe Their Effect on Model Convergence

# %% [markdown]
# ### Train the Model and Observe Convergence

# %%
# Initialize and train the model
model = LinearRegressionGD(learning_rate=0.01, n_iterations=1000)
model.fit(X_train, y_train)

print("Model training complete.")
# Out:
# Model training complete.

# %%
import matplotlib.pyplot as plt

# Plot the cost history
fig = plt.figure(figsize=(10, 6))
plt.plot(range(model.n_iterations), model.cost_history)
plt.xlabel('Number of Iterations')
plt.ylabel('Cost (MSE)')
plt.title('Cost vs. Number of Iterations')
plt.grid(True)
plt.show()

# # @title step_artifacts (Removed the undefined function call)
# num_fig = "1" # @param {type:"string"}
# step = 'ModelTraining'  # @param ["DataLoading", "DataExploration", "DataCleaning", "DataWrangling", "DataVisualization", "DataSplitting", "ModelDevelopment", "ModelOptimization", "ModelEvaluation", "Summary"] {type:"string"}
# upload_plt_to_gcs(num_fig, step, fig)

# %% [markdown]
# ## Task 7: Plot the Loss (Cost) versus the Number of Iterations

# %%
learning_rates = [0.001, 0.01, 0.1]
n_iterations = 1000
cost_histories = {}

plt.figure(figsize=(12, 8))

for lr in learning_rates:
    print(f"Training with learning rate: {lr}")
    model_lr = LinearRegressionGD(learning_rate=lr, n_iterations=n_iterations)
    model_lr.fit(X_train, y_train)
    cost_histories[lr] = model_lr.cost_history
    plt.plot(range(n_iterations), model_lr.cost_history, label=f'LR = {lr}')

plt.xlabel('Number of Iterations')
plt.ylabel('Cost (MSE)')
plt.title('Cost vs. Number of Iterations for Different Learning Rates')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Training with learning rate: 0.001
# Training with learning rate: 0.01
# Training with learning rate: 0.1

# %% [markdown]
# # Task 8: Evaluate the Trained Model using:
# *   Mean Absolute Error (MAE)
# *   Mean Squared Error (MSE)
# *   Root Mean Squared Error (RMSE)
# *   R² Score

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Make predictions on the test set using the model trained with LR=0.01
y_pred = model.predict(X_test)

# Calculate evaluation metrics
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse) # RMSE is the square root of MSE
r2 = r2_score(y_test, y_pred)

print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"R-squared (R2) Score: {r2:.4f}")
# Out:
# Mean Absolute Error (MAE): 3.3977
# Mean Squared Error (MSE): 17.6214
# Root Mean Squared Error (RMSE): 4.1978
# R-squared (R2) Score: 0.1406
